# %%
#CRD Fund Check
#Developed by: ASkotnicki
#Version: 1.0
#Created: 18/01/2021
#Last Edited: 01/03/2021
#Last edit: Updated the input files to Feb / Jan 2021

# %% [markdown]
# ### Develop program for checking CRD holdings for fund changes

# %% [markdown]
# Program should include:
# - option to import CRD files
# - Functionality to detect new funds
# - Functionality to detect old funds
# - Functionality to detect interfunding changes that are due to either; new funds, terminated funds, or just interfunding changes
# - Resulting fund list should be divided as above
# - Should also include a mapping to fund names
# - Output in Excel with a section for notes

# %% [markdown]
# ### Import relevant libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Create classes

# %%
class CompareCRD:
    
    """Object to compare the changes in fund lists between two sets of Charles River Holdings Data"""
    
    def __init__(self, current_excel, current_sheet, previous_excel, previous_sheet):
        self.current_excel = current_excel
        self.current_sheet = current_sheet
        self.current = self._current_df()
        
        self.previous_excel = previous_excel
        self.previous_sheet = previous_sheet
        self.previous = self._previous_df()
        
        self.current_units = self._current_units()
        self.previous_units = self._previous_units()
        
    def _current_df(self):
        return pd.read_excel(self.current_excel, self.current_sheet)
    
    def _previous_df(self):
        return pd.read_excel(self.previous_excel, self.previous_sheet)
    
    def _current_units(self):
        units = self.current[(self.current.SEC_TYP_CD=='UNIT') | (self.current.SEC_TYP_CD == 'UNITA')]
        units['interfunding_code'] = units.ACCT_CD.astype(str) + ' ' + units.EXT_SEC_ID.astype(str)
        units = units[['ACCT_CD','EXT_SEC_ID','interfunding_code']]
        units.columns = ['child','parent','interfunding_code']
        units['parent'] = units.child.str.replace(r'UT$','')
        units['interfunding_code'] = units.interfunding_code.str.replace(r'UT$','')
        
        return units
    
    def _previous_units(self):
        units = self.previous[(self.previous.SEC_TYP_CD=='UNIT') | (self.previous.SEC_TYP_CD == 'UNITA')]
        units['interfunding_code'] = units.ACCT_CD.astype(str) + ' ' + units.EXT_SEC_ID.astype(str)
        units = units[['ACCT_CD','EXT_SEC_ID','interfunding_code']]
        units.columns = ['child','parent','interfunding_code']
        units['parent'] = units.child.str.replace(r'UT$','')
        units['interfunding_code'] = units.interfunding_code.str.replace(r'UT$','')
        
        return units
    
    def new_funds(self):
        new_funds = []
        
        for i in self.current['ACCT_CD'].unique() :
            if i not in self.previous['ACCT_CD'].unique() :
                new_funds.append(i)
                
        return new_funds
    
    def terminated_funds(self):
        terminated_funds = []
        
        for i in self.previous['ACCT_CD'].unique() :
            if i not in self.current['ACCT_CD'].unique() :
                terminated_funds.append(i)
                
        return terminated_funds
    
    def total_new_interfund_rels(self):
        new_interfunds = []
        
        for i in self.current_units['interfunding_code'].unique():
            if i not in self.previous_units['interfunding_code'].unique():
                new_interfunds.append(i)
                
        return new_interfunds 
    
    def total_terminated_interfund_rels(self):
        terminated_interfunds = []
        
        for i in self.previous_units['interfunding_code'].unique():
            if i not in self.current_units['interfunding_code'].unique():
                terminated_interfunds.append(i)
                
        return terminated_interfunds
    
    def new_fund_interfunds(self):
        """This function returns a list of new interfunding relationships that have occurred because of the creation 
        of a new parent fund"""
        new_fund_interfund = []
        
        input_one = self.total_new_interfund_rels()
        input_two = self.new_funds()
        
        output = [i for e in input_two for i in input_one if e in i]
        
        return output
    
    def terminated_fund_interfunds(self):
        """This function returns a list of terminated interfunding relationships that have occurred because of the
        termination of the old parent fund"""
        terminated_fund_interfund = []
        
        input_one = self.total_terminated_interfund_rels()
        input_two = self.terminated_funds()
        
        output = [i for e in input_two for i in input_one if e in i]
        
        return output
    
    def other_new_interfunds(self):
        """This function returns a list of new interfunding relationships that are not explaied by new parent fund
        creation"""
        input_one = self.total_new_interfund_rels()
        input_two = self.new_fund_interfunds()
        
        output = [b for b in input_one if
          all(a not in b for a in input_two)]
        
        return output
    
    def other_term_interfunds(self):
        """This function returns a list of old interfunding relationships that are not explained by parent fund
        termination"""
        input_one = self.total_terminated_interfund_rels()
        input_two = self.terminated_fund_interfunds()
        
        output = [b for b in input_one if
          all(a not in b for a in input_two)]
        
        return output
    
    def summary_new_funds(self):
        """This function returns a dataframe of new funds created along with a blank comments section"""
        df = pd.DataFrame(self.new_funds(),columns=['fund_code'])
        df['comments'] = ''
        df['change_management_required'] = ''
        df.set_index('fund_code',inplace=True)
        
        return df
    
    def summary_terminated_funds(self):
        """This function returns a dataframe of new funds created along with a blank comments section"""
        df = pd.DataFrame(self.terminated_funds(),columns=['fund_code'])
        df['comments'] = ''
        df['change_management_required'] = ''
        df.set_index('fund_code',inplace=True)
        
        return df
    
    def summary_interfunding(self):
        """This function returns a dataframe with interfunding relationship changes and blank comments section"""
        df_new = pd.DataFrame(self.new_fund_interfunds(),columns=['interfunding_code'])
        df_new[['child','parent']] = df_new.interfunding_code.str.split(' ', n=1, expand=True)
        df_new['reason'] = 'new fund creation'
        
        df_new_oth = pd.DataFrame(self.other_new_interfunds(),columns=['interfunding_code'])
        df_new_oth[['child','parent']] = df_new_oth.interfunding_code.str.split(' ', n=1, expand=True)
        df_new_oth['reason'] = 'new interfunding relationship'
        
        df_term = pd.DataFrame(self.terminated_fund_interfunds(),columns=['interfunding_code'])
        df_term[['child','parent']] = df_term.interfunding_code.str.split(' ', n=1, expand=True)
        df_term['reason'] = 'old fund terminated'
        
        df_term_oth = pd.DataFrame(self.other_term_interfunds(),columns=['interfunding_code'])
        df_term_oth[['child','parent']] = df_term_oth.interfunding_code.str.split(' ', n=1, expand=True)
        df_term_oth['reason'] = 'old interfunding relationship'
        
        df_all = pd.concat([df_new, df_new_oth, df_term, df_term_oth])
        df_all.set_index('interfunding_code',inplace=True)
        df_all['comments'] = ''
        df_all['change_management_required'] = ''
        
        return df_all

# %%
fund_codes = pd.read_excel(r'fundcodes.xlsx','fundcodes')

# %%
fund_codes.head()
# Out:
#   fund_code                                          fund_name
# 0      2BGF  WESTPAC VARIABLE INCOME PLAN - BALANCED GROWTH...
# 1      2CGP  WESTPAC VARIABLE INCOME PLAN - CASH GUARANTEED...
# 2      2GPP  WESTPAC VARIABLE INCOME PLAN - GROWTH PLUS (PUPS)
# 3      2MGF  WESTPAC VARIABLE INCOME PLAN - MODERATE GROWTH...
# 4      2MGP  WESTPAC VARIABLE INCOME PLAN - MANAGED GROWTH ...

# %%
fund_code_dict = dict(zip(fund_codes.fund_code, fund_codes.fund_name))

# %%
fund_code_dict
# Out:
# {'2BGF': 'WESTPAC VARIABLE INCOME PLAN - BALANCED GROWTH (PUPS)',
#  '2CGP': 'WESTPAC VARIABLE INCOME PLAN - CASH GUARANTEED (PUPS)',
#  '2GPP': 'WESTPAC VARIABLE INCOME PLAN - GROWTH PLUS (PUPS)',
#  '2MGF': 'WESTPAC VARIABLE INCOME PLAN - MODERATE GROWTH (PUPS)',
#  '2MGP': 'WESTPAC VARIABLE INCOME PLAN - MANAGED GROWTH (PUPS)',
#  '3BGF': 'WESTPAC FOUNDATION PLAN - BALANCED GROWTH (PUPS)',
#  '3CBP': 'WESTPAC INVESTMENT & PROTECTION PLAN - CASH BASED (PUPS)',
#  '3CPP': 'WESTPAC FOUNDATION PLAN - CASH PLUS PORTFOLIO (PUPS)',
#  '3DGF': 'WESTPAC UNIVERSAL LIFE -  DYNAMIC GROWTH (PUPS)',
#  '3DGP': 'WESTPAC  INSURANCE  BOND - DYNAMIC GROWTH (PUPS)',
#  '3DIG': 'WESTPAC FOUNDATION PLAN - DIVERSIFIED GROWTH (PUPS)',
#  '3DSP': 'WESTPAC FOUNDATION PLAN - DIVERSIFIED STABLE (PUPS)',
#  '3GAF': 'WESTPAC UNIVERSAL LIFE -  GROWTH ASSETS (PUPS)',
#  '3GAP': 'WESTPAC  INSURANCE  BOND - GROWTH ASSETS (PUPS)',
#  '3GPP': 'WESTPAC INVESTMENT & PROTECTION PLAN - GROWTH PLUS (PUPS)',
#  '3IAF': 'WESTPAC UNIVERSAL LIFE -  INCOME ACCUMULATION (PUPS)',
#  '3IAP': 'WESTPAC  INSURANCE  BOND - INCOME ACCUMULATION (PUPS)',
#  '3LTP': 'WESTPAC FOUNDATION PLAN - LONG TERM GROWTH (PUPS)',
#  '3MGF': 'WESTPAC FOUNDATION PLAN - MODERATE GROWTH (PUPS)',
#  '3MGP': 'WESTPAC INVMT & PROTECTION PLAN - MANAGED GROWTH (PUPS)',
#  '3MMF': 'WESTPAC FOUNDATION PLAN - MONEY MARKET (PUPS)',
#  '5CBP': 'WESTPAC ROLLOVER INVESTMENT BOND - CASH BASED (PUPS)',
#  '5GPP': 'WESTPAC ROLLOVER INVESTMENT BOND - GROWTH PLUS (PUPS)',
#  '5MGP': 'WESTPAC ROLLOVER INVESTMENT BOND - MANAGED GROWTH (PUPS)',
#  '5SBG': 'WESTPAC ROLLOVER INVESTMENT BOND - BALANCED GROWTH (PUPS)',
#  '5SCG': 'WESTPAC ROLLOVER INVESTMENT BOND - CAPITAL GUARANT (PUPS)',
#  906641: 'WBC LIFE INSURANCE SERVICES',
#  'ADHGUT': 'High Growth Multi-Blend Fund Pooled',
#  'ADMBFIBT': 'Advance Australian Fixed Interest Multi-Blend Fund',
#  'ADMFGF': 'Growth Multi-Blend Fund Pooled',
#  'ADMIEF': 'Defensive Multi-Blend fund Pooled',
#  'ADMIGF': 'Balanced Multi-Blend Fund Pooled',
#  'ADMMUT': 'Moderate Multi-Blend Fund Pooled',
#  'BAL': 'Balanced Model',
#  'BIFGIF': 'BT Wrap Ess BT Geared Imputation Fund',
#  'BIFW41': 'BT W/S PCO FUND',
#  'BIFW42': 'BT W/S PM FUND',
#  'BIFW43': 'BT W/S PAB FUND',
#  'BIFW44': 'BT W/S PFG FUND',
#  'BIFW45': 'BT W/S PHG FUND',
#  'BR': 'Balanced Trusts',
#  'BRF': 'BT Balanced Returns Fund',
#  'BTAABF': 'Pendal Government Bond Fund',
#  'BTAAMCO': 'Advance Asset Management - Australian Shares Multi-Blend',
#  'BTABAL': 'BT Active Balanced Fund',
#  'BTAIF': 'Pendal Monthly Income Plus Fund',
#  'BTAIFMDL': 'BTAIF Model',
#  'BTALVS': 'Pendal Active Long Volatility Fund',
#  'BTCFMIP': 'Commonwealth Fixed Interest Fund 14',
#  'BTCFMIPMDL': 'BTCFMIP Model',
#  'BTCS': 'Pendal Sustainable Balanced Fund',
#  'BTDGEF': 'Pendal Diversified Global Equity Fund',
#  'BTDGEFB': 'BTDGEF - Regional Benchmarks',
#  'BTDIF': 'Pendal Dynamic Income Fund',
#  'BTDIT': 'Pendal Dynamic Income Trust',
#  'BTDYEQ': 'Pendal Dynamic Global Equity Fund',
#  'BTFIDE': 'Fiducian Funds - Australian Shares Trust',
#  'BTGMAC2': 'BT Global Macro Fund - test',
#  'BTGPSF': 'Pendal Global Property Securities Fund',
#  'BTHAFI': 'Pendal High Alpha Fixed Interest Fund',
#  'BTHGF': 'Pendal Active High Growth Fund',
#  'BTHGFMDL': 'BTHGFMDL',
#  'BTHIAL': 'Pendal Focus Australian Share Fund',
#  'BTINDBAL': 'BT INDEX BALANCED FUND',
#  'BTINDDEF': 'BT INDEX DEFENSIVE FUND',
#  'BTINDGRO': 'BT INDEX GROWTH FUND',
#  'BTINDHGF': 'BT INDEX HIGH GROWTH FUND',
#  'BTINDMOD': 'BT INDEX MODERATE FUND',
#  'BTJGF': 'BT Japanese Share Fund',
#  'BTLGSS': 'Local Government Superannuation Scheme',
#  'BTLS1940A': "1940'S LIFESTAGE FUND - A",
#  'BTLS1950A': "1950'S LIFESTAGE FUND - A",
#  'BTLS1960A': "1960'S LIFESTAGE FUND - A",
#  'BTLS1970A': "1970'S LIFESTAGE FUND - A",
#  'BTLS1980A': "1980'S LIFESTAGE FUND - A",
#  'BTLS1990A': "1990'S LIFESTAGE FUND - A",
#  'BTMATR_CSH': 'MATR Cash',
#  'BTMBF': 'Pendal Active Moderate Fund',
#  'BTMCAP': 'Pendal MicroCap Opportunities Fund',
#  'BTMF': 'BT Balanced Returns PST',
#  'BTMIDCAP': 'Pendal MidCap Fund',
#  'BTPAF3X': 'Pendal Pure Alpha Fixed Income Trust - Class B',
#  'BTPAFI': 'Pendal Pure Alpha Fixed Income Fund',
#  'BTRPF': 'Pendal Risk Parity Fund',
#  'BTSAFI': 'Pendal Sustainable Australian Fixed Interest Fund',
#  'BTSPECPROP': 'Pendal Property Securities Fund',
#  'BTSTAGDC': 'Alpha Fixed Interest Mandate - Defined Contribution',
#  'BTWCPF': 'Pendal Credit Income Fund',
#  'BTWCSA': 'Return to Work Corporation of South Australia',
#  'BTWGPF': 'BT Global Property Fund',
#  'CMT': 'BT Cash Management Trust',
#  'CNTP': 'Pendal Active Conservative Fund',
#  'CON': 'Conservative Model',
#  'EQUI': 'BT Australian Share Fund',
#  'FGF': 'BT Future Goals Fund',
#  'GBTEST': "George's Test Portfolio",
#  'GROWTH': 'BT Split Growth Fund',
#  'GROWTHMDL': 'GROWTHMDL',
#  'GRWTH': 'Growth Model',
#  'IIC-CA': 'Westpac International Share Fund',
#  'IMA2': 'IMA2 Model',
#  'INCTRAD': 'BT Split Income Fund',
#  'INCTRADMDL': 'INCTRADMDL',
#  'IPF': 'BT Income Plus Fund',
#  'IPFMDL': 'IPFMDL',
#  'KIRIBA': 'KIRIBATI PROVIDENT FUND',
#  'KIRIBAMDL': 'Kiriba Model',
#  'LTGF': 'Westpac Dynamic Growth Fund',
#  'MAI_AMPMMS': 'Model AMP Multi Manager SMA',
#  'MAI_MA30': 'MAI Model - SMA 30/70',
#  'MAI_MA50': 'MAI Model - SMA 50/50',
#  'MAI_MA60': 'MAI Model - SMA 60/40',
#  'MAI_MA70': 'MAI Model - SMA 70/30',
#  'MAI_MA85': 'MAI Model - SMA 85/15',
#  'MAI_PDPSSB': 'Model Prime Super Sustainable Balanced',
#  'MAI_RATRF': 'MAI Model - RATRF',
#  'MDIV_CSH': 'DIV Model - Cash',
#  'MEZAMER': 'Pendal American Share Fund',
#  'MEZEURO': 'Pendal European Share Fund',
#  'MEZFGF': 'Pendal Active Growth Fund',
#  'MFTP': 'Pendal Balanced Returns Fund',
#  'MIF': 'BT Monthly Income Fund',
#  'MIFMDL': 'MIFMDL',
#  'MIFP': 'Westpac Conservative Growth Fund',
#  'MIFPMDL': 'MIFPMDL',
#  'MMWACC': 'BT Multi-manager Accumulator Fund',
#  'MMWBAL': 'BT Multi-Manager Balanced Fund',
#  'MMWCON': 'BT Multi-Manager Conservative Fund',
#  'MMWDSH': 'BT Multi-Manager High Growth Fund',
#  'MMWGRW': 'BT Multi-Manager Growth Fund',
#  'MMWMOD': 'BT W/S MULTI-MGR MODERATE FUND',
#  'MMWPRO': 'BT Multi-Manager Protector Fund',
#  'MOD': 'Moderate Model',
#  'MPSAF2': 'Managed Portfolio Series Aus Fixed Interest Fund 2 - Pendal',
#  'NKSBAL': 'KiwiSaver Balanced Fund',
#  'NKSCAS': 'KiwiSaver Cash Fund',
#  'NKSCON': 'KiwiSaver Conservative Fund',
#  'NKSCP4': 'Westpac Kiwisaver - Capital Protection Plan 4',
#  'NKSCP5': 'Westpac Kiwisaver - Capital Protection Plan 5',
#  'NKSDEF': 'KIWISAVER DEFAULT FUND',
#  'NKSGRO': 'KiwiSaver Growth Fund',
#  'NKSMOD': 'WESTPAC KIWISAVER MODERATE FUND',
#  'NLFLFE': 'Westpac Life-NZ-Limited Statutory Fund No.1',
#  'NLFSHF': 'Westpac Life-NZ-Limited Shareholder Fund',
#  'NPSADF': 'BT Private Selection Australasian Diversified Share Fund',
#  'NPSCAF': 'BT Private Selection Enhanced Cash Fund',
#  'NPSCBF': 'BT Private Selection Corporate Bond Fund',
#  'NPSGDBF': 'BT Private Selection Global Diversified Bond Fund',
#  'NPSMIS': 'BT Private Selection Multi Manager International Share Fund',
#  'NPSPRF': 'Westpac Premium Investment Property Fund',
#  'NRSACC': 'Westpac Retirement Plan – Accumulation Portfolio',
#  'NRSBAL': 'Westpac Retirement Plan - Balanced Portfolio',
#  'NRSDYN': 'Westpac Retirement Plan - Dynamic Portfolio',
#  'NRUAIS': 'Westpac Active Income Strategies Trust',
#  'NRUAMT': 'Westpac Active Moderate Trust',
#  'NRUDIV': 'Westpac Active Balanced Trust',
#  'NRUGWT': 'Westpac Active Growth Trust',
#  'NRUIPT': 'Westpac Active Conservative Trust',
#  'NSP-AS': 'WSSP Australian Equities Trust - BTIM (Stable Core)',
#  'NWUADF': 'Westpac Wholesale Australasian Diversified Share Trust',
#  'NWUIEF': 'Westpac Wholesale Multi Manager International Share Trust',
#  'NWUIEH': 'Westpac WHS Hedged International Share',
#  'NWUNFF': 'Westpac Wholesale New Zealand Bond No.1 Trust',
#  'NWUSTG': 'Westpac Wholesale Strategy Share',
#  'PDAMPMMS': 'AMP Multi Manager SMA',
#  'PDCRIMPT': 'Regnan Credit Impact Trust',
#  'PDFAEF': 'Pendal Focus Australian Equities Fund',
#  'PDIOOFEC': 'IOOF MultiMix Enhanced Cash Fund',
#  'PDMA70': 'PDMA70 - PENDAL MULTI ASSET SMA 70/30',
#  'PDPSSB': 'Prime Super Sustainable Balanced Fund',
#  'PPSBAL': 'PPS - Westpac Diversified Growth Fund',
#  'PPSBALMDL': 'PPSBALMDL',
#  'PPSDIF': 'PPS - Westpac Moderate Growth Fund',
#  'PPSDIFMDL': 'PPSDIFMDL',
#  'RAACA': 'Anglican Church of Australia',
#  'RAAES': 'Pendal Australian Share Trust',
#  'RAASF': 'BT Core Australian Share Fund',
#  'RAASI': 'BT Imputation Fund',
#  'RABAL': 'BT Active Balanced Fund - NEF',
#  'RABSTMDL': 'RABSTMDL',
#  'RACFBA': 'Commonwealth Diversified Fund 5',
#  'RACWT': 'Pendal Sustainable Conservative Fund',
#  'RADHF': 'BT Core Hedged Global Share Fund',
#  'RAESS': 'Pendal Ethical Share Trust',
#  'RAEST': 'Pendal Ethical Share Fund',
#  'RAFIW': 'Pendal Fixed Interest Fund',
#  'RAGFW': 'Pendal Global Fixed Interest Fund',
#  'RAGRO': 'BT Diversified Share Fund - NEF',
#  'RAGROMDL': 'RAGROMDL',
#  'RAGTW': 'Pendal Geared Imputation Fund',
#  'RAHYT': 'Pendal Enhanced Credit Fund',
#  'RAISF': 'BT Global Share Fund',
#  'RAISW': 'Pendal Concentrated Global Share Fund No.2',
#  'RALMT': 'Pendal Liquidity Management Trust',
#  'RAMWT': 'Pendal Active Balanced Fund',
#  'RAPSS': 'Pendal Property Trust',
#  'RAPSW': 'Pendal Property Investment Fund',
#  'RASCF': 'BT Smaller Companies Fund',
#  'RASCS': 'Pendal Smaller Companies Trust',
#  'RASCW': 'Pendal Smaller Companies Fund',
#  'RASIF': 'BT Fixed Interest Fund',
#  'RASIS': 'Pendal Imputation Trust',
#  'RASIW': 'Pendal Imputation Fund',
#  'RASWT': 'Pendal Australian Share Fund',
#  'RATEF': 'BT Tax Effective Income Fund - NEF',
#  'RATEFMDL': 'RATEFMDL',
#  'RATRF': 'Pendal Total Return Fund',
#  'SFLRCON': 'BT SUPER FOR LIFE - CONSERVATIVE FUND - RETIREMENT',
#  'SFLRGRO': 'BT SUPER FOR LIFE - GROWTH FUND - RETIREMENT',
#  'SFLRMOD': 'BT SUPER FOR LIFE - MODERATE FUND - RETIREMENT',
#  'SFLSCON': 'BT SUPER FOR LIFE - CONSERVATIVE FUND - SAVINGS',
#  'SFLSGRO': 'BT SUPER FOR LIFE - GROWTH FUND - SAVINGS',
#  'SFLSMOD': 'BT SUPER FOR LIFE - MODERATE FUND - SAVINGS',
#  'SMTP': 'BT Property Securities Fund',
#  'SPECASIA': 'Pendal Asian Share Fund',
#  'SPECAUST': 'Pendal Australian Equity Fund',
#  'SPECINTL': 'Pendal Concentrated Global Share Fund No.3',
#  'SUSTBAL': 'Sustainable Balanced',
#  'SUSTCON': 'Sustainable Conservative Model',
#  'TEBF': 'Westpac Balanced Growth Fund',
#  'TEIF': 'Westpac Moderate Growth Fund',
#  'Test_BTSASAG': 'model portfolio for BTSASAG (absolute)',
#  'TIME': 'BT Technology Fund',
#  'W1ASTM': 'Stat Fund No.1 (STM07) - Short Term',
#  'W1CSTM': 'Stat Fund No.1 (STMC4) - Short Term',
#  'W1RSTM': 'Stat Fund No.1 (STM01) - Short Term',
#  'W1SSTM': 'Stat Fund No.1 (STMSI) - Short Term',
#  'W2CSTM': 'Stat Fund No.2 (STMC2) - Short Term',
#  'W4STM': 'Stat Fund No.4 (STM06) - Short Term',
#  'W6CSTM': 'Stat Fund No.6 Short term Company',
#  'W6STM': 'Stat Fund No.6 (STMAF) - Short Term',
#  'W8STM': 'Stat Fund No.8 (STM08) - Short Term',
#  'W9OVR': 'Stat Fund No.9 (Shareholders OVR09) - Overlay',
#  'W9STM': 'Stat Fund No.9 (Shareholders STM09) - Short Term',
#  'WAAGSF': 'Westpac All Australian Growth Share Fund',
#  'WAATES': 'Westpac All Australian Tax Effective Share Fund',
#  'WAGSF': 'Westpac Australian Growth Share Fund',
#  'WAPSNF': 'Westpac Australian Property Securities Fund NEF',
#  'WASSF': 'Pendal Sustainable Australian Share Fund',
#  'WATENF': 'Westpac All Australian Tax Effective Share Fund NEF',
#  'WATESF': 'Westpac Australian Tax Effective Share Fund',
#  'WBGFNF': 'Westpac Balanced Growth Fund NEF',
#  'WGST': 'Westpac Australian Bond Fund',
#  'WMGFNF': 'Westpac Moderate Growth Fund NEF',
#  'WSP-IF': 'Pendal Enhanced Global Fixed Interest Fund',
#  'WSPP': 'Pendal Enhanced Property Securities Fund',
#  'WTMT': 'Pendal Short Term Income Securities Fund',
#  'BTGPS': 'Pendal Global Property Value Fund',
#  905062: 'BT Institutional Global Property Sector Trust',
#  'BTSIS': 'Pendal Sustainable International Share Fund',
#  'BTCOGS': 'Pendal Concentrated Global Share Fund',
#  'JOHECV': 'JOHCM European Concentrated Values',
#  'JOHEMO': 'JOHCM Global Emerging Markets Opportunities',
#  'BTISCPF': 'Pendal Stable Cash Plus Fund',
#  'RADHT': 'Pendal Core Hedged Global Share Fund',
#  'BTCRAUS': 'BTS - BT CORE AUST SHARES',
#  'PDCFSGE': 'Pendal CFS Commonwealth Global Shares Fund 8',
#  'ADMMBC': 'Advance Cash Multi-Blend Fund',
#  'AMER-BTI1': 'BT American Share Fund',
#  'BTALSFL': 'Pendal Australian Long/Short Fund - LONG ONLY',
#  'BTALSFS': 'Pendal Australian Long/Short Fund - SHORT ONLY',
#  'BTAMPAS': 'IPAC Specialist Investment Strategies',
#  'BTAMPCO': 'EFM Australian Share Fund 4',
#  'BTAMPTO': 'Ipac Income Generator',
#  'BTCFABF': 'Commonwealth Fixed Interest Fund 15',
#  'BTCFCPF': 'Commonwealth International Fixed Interest Fund 5',
#  'BTEM-BTEL': 'Pendal Gbl Em Mkts Opportunities Fund',
#  'BTFIDSC': 'Fiducian Australian Smaller Companies Shares Fund',
#  'BTHESTA': 'HEST Australia Limited',
#  'BTHESTAB': 'HESTA Australia Limited - Australian Fixed Interest',
#  'BTHOLO': 'HOSTPLUS Pooled Superannuation Fund',
#  'BTINFO': 'Intrust Super Fund',
#  'BTLGSR': 'LGIA Sustainable Australian Share Fund',
#  'BTLTIF': 'Pendal Long Term Income Fund',
#  'BTMEDIA': 'Media Super',
#  'BTMGIAT': 'Mercer Australian Sovereign Bond Fund',
#  'BTPACFI': 'PACCAR Australia Pty. Limited',
#  'BTPSCSH': 'BT Cash - FRN (Execution Only)',
#  'BTSASAG': 'State Super Alpha Fixed Interest Mandate',
#  'BTSASCO': 'State Super Active Australian Share Mandate',
#  'BTSIFI-BTHU': 'PENDAL SIFI Cash Portfolio (Alpha)',
#  'BTSIS-BTAU': 'Pendal Sustainable International Share Fund - Cash',
#  'BTSIS-BTGE': 'Pendal Sustainable International Share Fund',
#  'BTSTCODC': 'Active Australian Share Mandate - Defined Contribution',
#  'BTSTIF': 'Pendal Short Term Income Fund',
#  'BTSUNCA': 'Suncorp Cash  Fund',
#  'BTSUNCO': 'Suncorp Group Australian Equity Active Trust',
#  'BTTCIL': 'The Workers Compensation Insurance Fund',
#  'BTTELFO': 'Telstra Superannuation Scheme – Focus Fund',
#  'BTVET1SC': 'Victorian Funds Management Corp Equity Trust 1 (Small Cap)',
#  'BTVET2SC': 'Victorian Funds Management Corp Equity Trust 2 (Small Cap)',
#  'COREIEF-BTI4': 'Pendal International Share Fund',
#  'EURO-BTEJ': 'BT European Share Fund',
#  'GRAINS': 'Grains Research and Development Corporation',
#  'GRAINSCA': 'Grains Research and Development Corporation 2',
#  'INTL-BTI6': 'BT International Fund',
#  'JOHCOGS': 'Pendal JO Hambro COGS Open Ended Investment Company (OEIC)',
#  'MEZJAP-BTI8': 'Pendal Japanese Share Fund',
#  'PACI-BTJO': 'BT Asian Share Fund - JOH',
#  'PANTIME-BTJ3': 'Pendal Technology Trust',
#  'PBTDYAE': 'BT DYNAMIC MARKETS-AUST EQ- (PAPER PORTFOLIO)',
#  'PDBTSCA': 'BT Super Cash Fund',
#  'PDCFSAEQ': 'Commonwealth Australian Share Fund 31 - Pendal Sust Aust Sh',
#  'PDFEF': 'FUKOKU LIFE EUCALYPTUS FUND',
#  'PDGELO': 'GESB WA Treasury',
#  'PDMSSF': 'Mercer Sustainable Shares Fund',
#  'PDQACO': 'Qantas Superannuation Plan - Core',
#  'PDQSCA': 'Qantas Superannuation Limited Portfolio Cash 2',
#  'PDRUFS': 'UFS Responsible Australian Share Fund',
#  'PDSTIS': 'Pendal Short Term Income Securities Trust - AMP',
#  'PDTCORPAE': 'TCorpIM Australian Share Fund',
#  'RACFDE': 'Commonwealth Australian Share Fund 10',
#  'RACFDF': 'Commonwealth Fixed Interest Fund 6',
#  'RACFLP': 'Commonwealth Property Fund 2',
#  'RADGS-BTJ8': 'Pendal Core Global Share Trust',
#  'RAGTS': 'Pendal Geared Imputation Trust',
#  'RANRF': 'BT Natural Resources Fund',
#  'TELSTRA': 'Telstra Super Fund - Cash Management',
#  'W2CAFI': 'Stat Fund No.2 (FIMC2) - Australian Fixed Interest',
#  'W2CIFI': 'Stat Fund No.2 (IFMC2) - International Fixed Interest',
#  'W2STM': 'Stat Fund No.2 (STMW2) - Short Term',
#  'W3STM': 'Stat Fund No.3 (STMW3) - Short Term',
#  'W6FRN': 'Stat Fund No.6 - Floating Rate Notes',
#  'WAPSF': 'Westpac Australian Property Securities Fund',
#  'WSP-M2': 'Pendal Managed Cash Fund',
#  'RABST': 'BT Active Balanced PST',
#  'BTMATR': 'Pendal Multi-Asset Target Return Fund',
#  'RGPSAU': 'Pendal Global Property Trust',
#  'BTPAF1X': 'Pendal Pure Alpha Fixed Income Trust - Class A',
#  'MMWIS': 'BTI4 - BT CORE INT'}

# %% [markdown]
# # Testing

# %% [markdown]
# #### Current holdings

# %%
input_current = r'G:\IM Distribution Client Service\Research Reporting\1. SOURCE DATA\INTERNAL\CHARLES RIVER - SQL\CRTS210228.xlsx'
sheet_current = 'Sheet1'
input_previous = r'G:\IM Distribution Client Service\Research Reporting\1. SOURCE DATA\INTERNAL\CHARLES RIVER - SQL\CRTS210131.xlsx'
sheet_previous = 'Sheet1'

# %%
compare = CompareCRD(input_current, sheet_current, input_previous, sheet_previous)
# Out:
# <ipython-input-2-dc76a3412178>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   units['interfunding_code'] = units.ACCT_CD.astype(str) + ' ' + units.EXT_SEC_ID.astype(str)
# <ipython-input-2-dc76a3412178>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   units['interfunding_code'] = units.ACCT_CD.astype(str) + ' ' + units.EXT_SEC_ID.astype(str)

# %% [markdown]
# #### Create summary for new funds

# %%
interfunding_results = compare.summary_interfunding()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-200f5ba04c57> in <module>
# ----> 1 interfunding_results = compare.summary_interfunding()
#
# <ipython-input-2-dc76a3412178> in summary_interfunding(self)
#     144         """This function returns a dataframe with interfunding relationship changes and blank comments section"""
#     145         df_new = pd.DataFrame(self.new_fund_interfunds(),columns=['interfunding_code'])
# --> 146         df_new[['child','parent']] = df_new.interfunding_code.str.split(' ', n=1, expand=True)
#     147         df_new['reason'] = 'new fund creation'
#     148
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3035             self._setitem_frame(key, value)
#    3036         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3037             self._setitem_array(key, value)
#    3038         else:
#    3039             # set column
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    3061             if isinstance(value, DataFrame):
#    3062                 if len(value.columns) != len(key):
# -> 3063                     raise ValueError("Columns must be same length as key")
#    3064                 for k1, k2 in zip(key, value.columns):
#    3065                     self[k1] = value[k2]
#
# ValueError: Columns must be same length as key

# %%
interfunding_results['child_name'] = interfunding_results.child.map(fund_code_dict)
interfunding_results['parent_name'] = interfunding_results.parent.map(fund_code_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-5d0eb73ec508> in <module>
# ----> 1 interfunding_results['child_name'] = interfunding_results.child.map(fund_code_dict)
#       2 interfunding_results['parent_name'] = interfunding_results.parent.map(fund_code_dict)
#
# NameError: name 'interfunding_results' is not defined

# %%
terminated_results = compare.summary_terminated_funds()

# %%
terminated_results.head()
# Out:
#                   comments change_management_required  \
# fund_code
# 2BGF       terminated fund
# 2CGF       terminated fund
# 2CGP       terminated fund
# 2GPP       terminated fund
# 2MGF       terminated fund
#
#                                                    fund_name
# fund_code
# 2BGF       WESTPAC VARIABLE INCOME PLAN - BALANCED GROWTH...
# 2CGF                                                     NaN
# 2CGP       WESTPAC VARIABLE INCOME PLAN - CASH GUARANTEED...
# 2GPP       WESTPAC VARIABLE INCOME PLAN - GROWTH PLUS (PUPS)
# 2MGF       WESTPAC VARIABLE INCOME PLAN - MODERATE GROWTH...

# %%
terminated_results['comments'] = 'terminated fund'
terminated_results['fund_name'] = terminated_results.index.map(fund_code_dict)

# %%
terminated_results.head()
# Out:
#                   comments change_management_required  \
# fund_code
# 2BGF       terminated fund
# 2CGF       terminated fund
# 2CGP       terminated fund
# 2GPP       terminated fund
# 2MGF       terminated fund
#
#                                                    fund_name
# fund_code
# 2BGF       WESTPAC VARIABLE INCOME PLAN - BALANCED GROWTH...
# 2CGF                                                     NaN
# 2CGP       WESTPAC VARIABLE INCOME PLAN - CASH GUARANTEED...
# 2GPP       WESTPAC VARIABLE INCOME PLAN - GROWTH PLUS (PUPS)
# 2MGF       WESTPAC VARIABLE INCOME PLAN - MODERATE GROWTH...

# %%
new_results = compare.summary_new_funds()

# %%
new_results['comments'] = 'new fund created'
new_results['fund_name'] = new_results.index.map(fund_code_dict)

# %%
new_results.head()
# Out:
#                        comments change_management_required  fund_name
# fund_code
# BTPAF3X_ALVS   new fund created                                   NaN
# BTPAF3X_FI     new fund created                                   NaN
# BTPAF3X_MACRO  new fund created                                   NaN

# %%
all_results = pd.concat([new_results, terminated_results, interfunding_results])

# %%
all_results.head()
# Out:
#                  comments change_management_required  \
# SFLRCON  new fund created
# SFLRGRO  new fund created
# SFLRMOD  new fund created
# SFLSCON  new fund created
# SFLSGRO  new fund created
#
#                                                  fund_name child parent  \
# SFLRCON  BT SUPER FOR LIFE - CONSERVATIVE FUND - RETIRE...   NaN    NaN
# SFLRGRO       BT SUPER FOR LIFE - GROWTH FUND - RETIREMENT   NaN    NaN
# SFLRMOD     BT SUPER FOR LIFE - MODERATE FUND - RETIREMENT   NaN    NaN
# SFLSCON    BT SUPER FOR LIFE - CONSERVATIVE FUND - SAVINGS   NaN    NaN
# SFLSGRO          BT SUPER FOR LIFE - GROWTH FUND - SAVINGS   NaN    NaN
#
#         reason child_name parent_name
# SFLRCON    NaN        NaN         NaN
# SFLRGRO    NaN        NaN         NaN
# SFLRMOD    NaN        NaN         NaN
# SFLSCON    NaN        NaN         NaN
# SFLSGRO    NaN        NaN         NaN

# %%
all_results.tail()
# Out:
#              comments change_management_required fund_name  child   parent  \
# MFTP BTHGABF                                           NaN   MFTP  BTHGABF
# MFTP BTDYEQ                                            NaN   MFTP   BTDYEQ
# RAMWT WSP-IF                                           NaN  RAMWT   WSP-IF
# RAMWT JOHEMO                                           NaN  RAMWT   JOHEMO
# RAMWT BTDYEQ                                           NaN  RAMWT   BTDYEQ
#
#                                      reason                    child_name  \
# MFTP BTHGABF  old interfunding relationship  Pendal Balanced Returns Fund
# MFTP BTDYEQ   old interfunding relationship  Pendal Balanced Returns Fund
# RAMWT WSP-IF  old interfunding relationship   Pendal Active Balanced Fund
# RAMWT JOHEMO  old interfunding relationship   Pendal Active Balanced Fund
# RAMWT BTDYEQ  old interfunding relationship   Pendal Active Balanced Fund
#
#                                               parent_name
# MFTP BTHGABF                                          NaN
# MFTP BTDYEQ             Pendal Dynamic Global Equity Fund
# RAMWT WSP-IF   Pendal Enhanced Global Fixed Interest Fund
# RAMWT JOHEMO  JOHCM Global Emerging Markets Opportunities
# RAMWT BTDYEQ            Pendal Dynamic Global Equity Fund

# %% [markdown]
# # Output

# %% [markdown]
# ### Separate Excel Sheets

# %%
output_excel = 'CRD Jan 21 v2.xlsx'

# %%
with pd.ExcelWriter(output_excel, engine='openpyxl',mode='a') as writer :
    new_results.to_excel(writer,sheet_name='new funds')
    terminated_results.to_excel(writer, sheet_name='terminated funds')
    interfunding_results.to_excel(writer, sheet_name='interfunding changes')
